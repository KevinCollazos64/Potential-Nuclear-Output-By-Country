# %%
import pandas as pd

# %%
lithium = pd.read_csv('mcs2023-lithi_world.csv')
lithium_sali=pd.read_csv('mcs2023-lithi_salient.csv')
rareearth=pd.read_csv('mcs2023-raree_world.csv')
zirco_hafni=pd.read_csv('mcs2023-zirco-hafni_world.csv')
ocean=pd.read_csv('cleaned_wod_data.csv')

# %%
lithium
# Out:
#      Source                                           Country  \
# 0   MCS2023                                     United States
# 1   MCS2023                                         Argentina
# 2   MCS2023                                         Australia
# 3   MCS2023                                            Brazil
# 4   MCS2023                                            Canada
# 5   MCS2023                                             Chile
# 6   MCS2023                                             China
# 7   MCS2023                                          Portugal
# 8   MCS2023                                          Zimbabwe
# 9   MCS2023                                   Other countries
# 10  MCS2023  World total (rounded), excluding U.S. production
#
#                                 Type Prod_t_2021 Prod_t_est_2022  \
# 0   Mine production, lithium content           W               W
# 1   Mine production, lithium content        5970            6200
# ...

# %%
rareearth
# Out:
#      Source                Country  \
# 0   MCS2023          United States
# 1   MCS2023              Australia
# 2   MCS2023                 Brazil
# 3   MCS2023                  Burma
# 4   MCS2023                Burundi
# 5   MCS2023                 Canada
# 6   MCS2023                  China
# 7   MCS2023              Greenland
# 8   MCS2023                  India
# 9   MCS2023             Madagascar
# 10  MCS2023                 Russia
# 11  MCS2023           South Africa
# 12  MCS2023               Tanzania
# 13  MCS2023               Thailand
# 14  MCS2023                Vietnam
# 15  MCS2023        Other countries
# 16  MCS2023  World total (rounded)
#
#                                                  Type  Prod_t_2021  \
# 0   Rare earths, mine production, rare-earth-oxide...        42000
# 1   Rare earths, mine production, rare-earth-oxide...        24000
# 2   Rare earths, mine production, rare-earth-oxide...          500
# ...

# %%
zirco_hafni
# Out:
#     Source                Country  \
# 0  MCS2023          United States
# 1  MCS2023              Australia
# 2  MCS2023                  China
# 3  MCS2023              Indonesia
# 4  MCS2023             Mozambique
# 5  MCS2023                Senegal
# 6  MCS2023           South Africa
# 7  MCS2023        Other countries
# 8  MCS2023  World total (rounded)
#
#                                                 Type Prod_kt_est_2021  \
# 0  Zirconium ores and zircon concentrates, mine p...             <100
# 1  Zirconium ores and zircon concentrates, mine p...              500
# 2  Zirconium ores and zircon concentrates, mine p...              140
# 3  Zirconium ores and zircon concentrates, mine p...               55
# 4  Zirconium ores and zircon concentrates, mine p...              100
# 5  Zirconium ores and zircon concentrates, mine p...               64
# 6  Zirconium ores and zircon concentrates, mine p...              320
# ...

# %%
lithium_sali
# Out:
#   DataSource Commodity  Year USprod_t  Imports_t  Exports_t  Consump_t  \
# 0    MCS2023   Lithium  2018        W       3420       1660       3000
# 1    MCS2023   Lithium  2019        W       2620       1660       2000
# 2    MCS2023   Lithium  2020        W       2460       1200       2000
# 3    MCS2023   Lithium  2021        W       2640       1870       2000
# 4    MCS2023   Lithium  2022        W       3400       2700       3000
#
#    Price_dt  Employment_num NIR_pct
# 0     16000              70     >50
# 1     11700              70     >25
# 2      8400              70     >50
# 3     12600              70     >25
# 4     37000              70     >25
